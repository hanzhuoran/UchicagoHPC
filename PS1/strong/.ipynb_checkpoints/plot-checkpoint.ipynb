# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
f = open('data.txt', 'r')

# %%
L = 1
N = 400
x = np.linspace(0,L,N+1)
xmid = 1/2*(x[0:N]+x[1:N+1])
y = np.linspace(0,L,N+1)
ymid = 1/2*(x[0:N]+x[1:N+1])
X,Y = np.meshgrid(xmid, ymid)

# %%
data = np.loadtxt(f)

# %%
initial = data[0:400]
print(initial)
# Out:
# [[ 0.1223  0.0187  0.0191 ...,  0.0194  0.0191  0.0187]
#  [ 0.0187  0.0191  0.0194 ...,  0.0198  0.0194  0.0191]
#  [ 0.0191  0.0194  0.0198 ...,  0.0202  0.0198  0.0194]
#  ...,
#  [ 0.0194  0.0198  0.0202 ...,  0.0279  0.0202  0.0198]
#  [ 0.0191  0.0194  0.0198 ...,  0.0202  0.0198  0.0194]
#  [ 0.0187  0.0191  0.0194 ...,  0.0198  0.0194  0.0191]]

# %%
middle = data[400:800]
last = data[800:1200]

# %%
print(len(initial))
print(len(middle))
print(len(last))
# Out:
# 400
# 400
# 400

# %%
print(middle)
# Out:
# [[ 0.1244  0.1244  0.1244 ...,  0.1244  0.1244  0.1244]
#  [ 0.1244  0.1244  0.1244 ...,  0.1244  0.1244  0.1244]
#  [ 0.1244  0.1244  0.1244 ...,  0.1244  0.1244  0.1244]
#  ...,
#  [ 0.1244  0.1244  0.1244 ...,  0.1244  0.1244  0.1244]
#  [ 0.1244  0.1244  0.1244 ...,  0.1244  0.1244  0.1244]
#  [ 0.1244  0.1244  0.1244 ...,  0.1244  0.1244  0.1244]]

# %%
plt.pcolor(X, Y, initial, cmap='RdBu', vmax=abs(initial).max(), vmin=0)
plt.colorbar()
plt.show()

# %%
plt.pcolor(X, Y, middle, cmap='RdBu', vmax=abs(middle).max(), vmin=0)
plt.colorbar()
plt.show()

# %%
plt.pcolor(X, Y, last, cmap='RdBu', vmax=abs(last).max(), vmin=0)
plt.colorbar()
plt.show()
